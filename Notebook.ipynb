# %%
using Pkg
using DataFrames
using CSV
using Plots

# %%
df = CSV.read("GRB_data.txt",  DataFrame, header=[:logt90, :dlogt90, :logHR])
# Out:
# 1932×3 DataFrame
#   Row │ logt90     dlogt90     logHR
#       │ Float64    Float64     Float64
# ──────┼────────────────────────────────────
#     1 │  1.64558   0.0349151    0.419301
#     2 │  5.3403    0.00536016   0.0336968
#     3 │  1.14295   0.188138     0.589931
#     4 │  4.50176   0.00317158   0.501586
#     5 │  6.06382   0.00254409   0.036883
#     6 │  4.58676   0.0230403    0.52872
#     7 │  5.94345   0.0267333    0.0625971
#     8 │  4.31759   0.0170648    0.0542884
#     9 │  4.12636   0.00807076   0.427434
#    10 │  5.20409   0.00503252   0.00500581
#    11 │ -1.15518   0.0730159    0.97763
#   ⋮   │     ⋮          ⋮            ⋮
#  1923 │  4.10759   0.04625      0.591546
#  1924 │  3.85236   0.225692    -0.277453
#  1925 │ -0.669431  0.394531     0.874378
#  1926 │  3.18866   0.300792    -0.00635224
#  1927 │  2.71919   0.00599947   0.295579
#  1928 │  0.618424  0.380927     1.51905
#  1929 │  4.1865    0.170416    -0.244253
#  1930 │ -0.86275   0.151659     0.088253
#  1931 │  2.83086   0.0304245   -0.51647
#  1932 │  4.16982   0.212429     0.707479
#                           1911 rows omitted

# %%
histogram(df.logt90)
title!("GRB log(\$T_{90}\$) distribution, 1932 samples")
xlabel!("log(\$T_{90}\$)")
ylabel!("P(x)")
